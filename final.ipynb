# %%
# !pip install subprocess
# Out:
# ...
#   ERROR: Could not find a version that satisfies the requirement subprocess (from versions: none)
# ERROR: No matching distribution found for subprocess
# WARNING: You are using pip version 19.2.3, however version 25.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import subprocess

# Path to your venv python
PYTHON = r"venv\Scripts\python.exe"

# Path to main.py and your desired config
cmd = [
    PYTHON,
    "main.py",
    "--config",
    "config/model_rt_best.yaml"
]

result = subprocess.run(cmd, capture_output=True, text=True)

print(result.stdout)
print(result.stderr)
# Out:
# [INFO] Found NPZ file: data/train.npz
# [INFO] Found NPZ file: data/test.npz
# Already found a thresholded dataset!
#
# [2025-12-08 16:09:37] [INFO] Loaded config (config/model_rt_best.yaml)model:
#   name: randomized_tree
#   cv_folds: 5
#   n_jobs: -1
#   n_estimators: 1082
#   min_samples_split: 9
#   min_samples_leaf: 4
#   max_samples: 0.8736778581132036
#   bootstrap: true
#   max_features: sqrt
#   max_depth: 17
#   criterion: entropy
#   class_weight: balanced
#   random_state: 42
# preprocessing:
#   normalize: false
#   one_hot_encode:
#     enabled: true
#     columns:
#     - Isolation type
#     - Location
#     - Isolation source
#     - Testing standard
#   pca:
#     enabled: false
#     svd_solver: randomized
#   variance_threshold:
#     enabled: true
#     threshold: 0.1
#   select_variance_k:
#     enabled: false
#     k: 10000
#   select_xgboost_k:
#     enabled: false
#     k: 8000
#   select_k_best:
#     enabled: false
#     k: 200
#   select_first_k:
# ...
